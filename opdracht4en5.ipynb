# %%
import seaborn as sns
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.linear_model import LinearRegression #remember, this is linear regression model from sk-learn
from sklearn.model_selection import train_test_split #this is the function we need to split the data
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df_voetbal =pd.read_csv("CompleteDataset.csv")
df_voetbal.head()
# Out:
# C:\Users\jarne\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (23,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0               Name  Age  \
# 0           0  Cristiano Ronaldo   32
# 1           1           L. Messi   30
# 2           2             Neymar   25
# 3           3          L. Suárez   30
# 4           4           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# ...

# %%
df_subset=df_voetbal[["Name", "Preferred Positions"]]
df_subset.head()
# Out:
#                 Name Preferred Positions
# 0  Cristiano Ronaldo              ST LW
# 1           L. Messi                 RW
# 2             Neymar                 LW
# 3          L. Suárez                 ST
# 4           M. Neuer                 GK

# %%
split_data=df_subset["Preferred Positions"].str.split(" ")
data=split_data.to_list()
names=["1", "2", "3", "4","5"]
new_df = pd.DataFrame(data, columns=names)

# %%
Tevoorspellendata=new_df["1"]


new_df["Name"]=df_subset[["Name"]]
#Dataset met naam speler en favoriete positie.
df2=new_df[["Name", "1"]]

# %%
df2.head()
# Out:
#                 Name   1
# 0  Cristiano Ronaldo  ST
# 1           L. Messi  RW
# 2             Neymar  LW
# 3          L. Suárez  ST
# 4           M. Neuer  GK

# %% [markdown]
# We gaan nu 7 variabelen selecteren waarvan ik denk dat het kan helpen met voorspellen.

# %%
df3=df_voetbal[["Name","Ball control", "Dribbling", "Finishing", "Sliding tackle", "Sprint speed", "Stamina", "Interceptions"]]
df3["PP"]=df2[["1"]]
# Out:
# <ipython-input-21-1c9cd74a5130>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["PP"]=df2[["1"]]

# %%
df3.head(40)
# Out:
#                  Name Ball control Dribbling Finishing Sliding tackle  \
# 0   Cristiano Ronaldo           93        91        94             23
# 1            L. Messi           95        97        95             26
# 2              Neymar           95        96        89             33
# 3           L. Suárez           91        86        94             38
# 5      R. Lewandowski           89        85        91             19
# 7           E. Hazard           92        93        83             22
# 8            T. Kroos           89        79        76             69
# 9          G. Higuaín           85        84        91             18
# 10       Sergio Ramos           84        61        60             91
# 11       K. De Bruyne           87        85        83             40
# 13         A. Sánchez           87        90        85             35
# 14          L. Modrić           92        86        71             73
# ...

# %%
df3=df3[(df3["PP"] != "GK")] #Keepers er uit halen
df3.head()
# Out:
#                 Name Ball control Dribbling Finishing Sliding tackle  \
# 0  Cristiano Ronaldo           93        91        94             23
# 1           L. Messi           95        97        95             26
# 2             Neymar           95        96        89             33
# 3          L. Suárez           91        86        94             38
# 5     R. Lewandowski           89        85        91             19
#
#   Sprint speed Stamina Interceptions  PP
# 0           91      92            29  ST
# 1           87      73            22  RW
# 2           90      78            36  LW
# 3           77      89            41  ST
# 5           83      79            39  ST

# %%
df3["Interceptions"].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1536         try:
# -> 1537             x = float(x)
#    1538         except ValueError:
#
# ...

# %%
df3['PP'].value_counts() #Laat zien hoeveel spelers er zijn van elke positie
# Out:
# CB     2705
# ST     2277
# CM     1977
# CDM    1396
# RM     1350
# LM     1326
# LB     1309
# RB     1195
# CAM    1125
# RW      429
# LW      427
# CF      205
# LWB     120
# RWB     111
# Name: PP, dtype: int64

# %% [markdown]
# Nu gaan we dummie variabelen maken van alle positie's.

# %% [markdown]
# Lineaire regressie uitvoeren. Eerst splitsen in test en train sets.

# %%
x = df3.loc[:, ~df3.columns.isin(['PP_CB'])]
y = df3['PP_CB']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3,random_state=23) #splits the data into train (70%) and test (30%) data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PP_CB'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-d14d52e15ffe> in <module>
# ...
